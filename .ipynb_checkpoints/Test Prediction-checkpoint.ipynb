# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set()

# %%
training = pd.read_csv('train.csv', index_col=0)
testing = pd.read_csv('test.csv', index_col=0)

testing['Survived'] = np.NaN

# %%
training
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
# %matplotlib inline
training.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
training.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Some of the information above isn't really helpful.
# No one 38% survived.
# Things like survival and class aren't numbers we can average. They're categorical.
# Other things like Age and Fare can tell us more. They're numerical.
# Let's separate numerical and categorical data so we can get rid of some of the noise
numdata = training[['Age','SibSp','Parch','Fare']]
catdata = training[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

# %%
numdata.describe()
# Out:
#               Age       SibSp       Parch        Fare
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118    0.523008    0.381594   32.204208
# std     14.526497    1.102743    0.806057   49.693429
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    0.000000    0.000000    7.910400
# 50%     28.000000    0.000000    0.000000   14.454200
# 75%     38.000000    1.000000    0.000000   31.000000
# max     80.000000    8.000000    6.000000  512.329200

# %%
# So the average age on the Titanic was a little more than twenty-nine and a half.
# The youngest kid wasn't even a year old.
# And the oldest person was 80.
# Most people didn't have a sibling or spouse on board.
# But at least one person had eight siblings (or spouses, but hopefully siblings).
# All interesting data.
# Let's look at some more number-based data.
training [["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
# So the average age on the Titanic was a little higher for men than women.
training.groupby(["Sex", "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
# So women across the board paid more regardless of which class they were in.
# Which is interesting, though maybe not important for our goal
training ["SibSp"].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
# So most of the passengers did not have a spouse or sibling onboard
# Of those that did most only had one.
# There were five people who had five spouses or siblings - hopefully siblings.
training.groupby(["SibSp", "Pclass"])["Age"].mean()
# Out:
# SibSp  Pclass
# 0      1         39.181416
#        2         31.934220
#        3         27.630201
# 1      1         37.414154
#        2         27.363636
#        3         24.912698
# 2      1         37.200000
#        2         19.125000
#        3         18.875000
# 3      1         22.000000
#        2         30.000000
#        3          8.875000
# 4      3          7.055556
# 5      3         10.200000
# 8      3               NaN
# Name: Age, dtype: float64

# %%
# So it looks like the average ages for people with no siblings or spouse onboard were older than those with.
# And there was no one in first or second class with more than three siblings or a sibling/spouse combo of more than three.
training ["Parch"].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 3      5
# 5      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
# So most people didn't have a parent or child onboard
print(numdata.corr())
sns.heatmap(numdata.corr())
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.308247 -0.189119  0.096067
# SibSp -0.308247  1.000000  0.414838  0.159651
# Parch -0.189119  0.414838  1.000000  0.216225
# Fare   0.096067  0.159651  0.216225  1.000000
# <AxesSubplot:>

# %%
# This is ripped straight from Ken Jee's tutorial.
# It has the desired effect of getting rid of the name (something we proved earlier doesn't parse)
# And in turn making something parsable, ie Title.
training['Title'] = training.Name.apply(lambda x: x.split(',')[1].split('.')[0].strip())
training['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Major             2
# Mlle              2
# Col               2
# Jonkheer          1
# Capt              1
# Don               1
# Mme               1
# Ms                1
# the Countess      1
# Sir               1
# Lady              1
# Name: Title, dtype: int64

# %%
training['MultipleCabins'] = training.Cabin.apply(lambda x: 0 if pd.isna(x) else len(x.split(' ')))
training['MultipleCabins'].value_counts()
# Out:
# 0    687
# 1    180
# 2     16
# 3      6
# 4      2
# Name: MultipleCabins, dtype: int64

# %%
training['CabinDeck'] = training.Cabin.apply(lambda x: str(x)[0])
print(training.CabinDeck.value_counts())
# Out:
# n    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: CabinDeck, dtype: int64

# %%
training [training ["Name"].str.contains("Lee")]
# Out:
#              Survived  Pclass                               Name   Sex   Age  \
# PassengerId
# 75                  1       3                      Bing, Mr. Lee  male  32.0
# 170                 0       3                      Ling, Mr. Lee  male  28.0
# 554                 1       3  Leeni, Mr. Fahim ("Philip Zenni")  male  22.0
#
#              SibSp  Parch Ticket     Fare Cabin Embarked Title  \
# PassengerId
# 75               0      0   1601  56.4958   NaN        S    Mr
# 170              0      0   1601  56.4958   NaN        S    Mr
# 554              0      0   2620   7.2250   NaN        C    Mr
#
#              MultipleCabins CabinDeck
# PassengerId
# 75                        0         n
# 170                       0         n
# 554                       0         n

# %%
testing['MultipleCabins'] = testing.Cabin.apply(lambda x: 0 if pd.isna(x) else len(x.split(' ')))
testing['MultipleCabins'].value_counts()
# Out:
# 0    327
# 1     74
# 2     10
# 3      4
# 4      3
# Name: MultipleCabins, dtype: int64

# %%
testing['Title'] = testing.Name.apply(lambda x: x.split(',')[1].split('.')[0].strip())
testing['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Dr          1
# Dona        1
# Ms          1
# Name: Title, dtype: int64

# %%
testing['CabinDeck'] = testing.Cabin.apply(lambda x: str(x)[0])
testing['CabinDeck'].value_counts()
# Out:
# n    327
# C     35
# B     18
# D     13
# E      9
# F      8
# A      7
# G      1
# Name: CabinDeck, dtype: int64

# %%
training.Age = training.Age.fillna(training.Age.median())

# %%
testing.Age = testing.Age.fillna(testing.Age.median())

# %%
training.dropna(subset=['Embarked'],inplace = True)

# %%
testing.dropna(subset=['Embarked'], inplace = True)

# %%
training.Pclass = training.Pclass.astype(str)

# %%
testing.Pclass = testing.Pclass.astype(str)

# %%
training
# Out:
#              Survived Pclass  \
# PassengerId
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 4                1      0            113803  53.1000  C123        S   Mrs
# 5                0      0            373450   8.0500   NaN        S    Mr
# ...            ...    ...               ...      ...   ...      ...   ...
# 887              0      0            211536  13.0000   NaN        S   Rev
# 888              0      0            112053  30.0000   B42        S  Miss
# 889              1      2        W./C. 6607  23.4500   NaN        S  Miss
# 890              0      0            111369  30.0000  C148        C    Mr
# 891              0      0            370376   7.7500   NaN        Q    Mr
#
#              MultipleCabins CabinDeck
# PassengerId
# 1                         0         n
# 2                         1         C
# 3                         0         n
# 4                         1         C
# 5                         0         n
# ...                     ...       ...
# 887                       0         n
# 888                       1         B
# 889                       0         n
# 890                       1         C
# 891                       0         n
#
# [889 rows x 14 columns]

# %%
testing
# Out:
#             Pclass                                          Name     Sex  \
# PassengerId
# 892              3                              Kelly, Mr. James    male
# 893              3              Wilkes, Mrs. James (Ellen Needs)  female
# 894              2                     Myles, Mr. Thomas Francis    male
# 895              3                              Wirz, Mr. Albert    male
# 896              3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...            ...                                           ...     ...
# 1305             3                            Spector, Mr. Woolf    male
# 1306             1                  Oliva y Ocana, Dona. Fermina  female
# 1307             3                  Saether, Mr. Simon Sivertsen    male
# 1308             3                           Ware, Mr. Frederick    male
# 1309             3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305         27.0      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308         27.0      0      0              359309    8.0500   NaN        S
# 1309         27.0      1      1                2668   22.3583   NaN        C
#
#              Survived  MultipleCabins   Title CabinDeck
# PassengerId
# 892               NaN               0      Mr         n
# 893               NaN               0     Mrs         n
# 894               NaN               0      Mr         n
# 895               NaN               0      Mr         n
# 896               NaN               0     Mrs         n
# ...               ...             ...     ...       ...
# 1305              NaN               0      Mr         n
# 1306              NaN               1    Dona         C
# 1307              NaN               0      Mr         n
# 1308              NaN               0      Mr         n
# 1309              NaN               0  Master         n
#
# [418 rows x 14 columns]

# %%
traindum = pd.get_dummies(training[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked','Title', 'MultipleCabins', 
                                    'CabinDeck']])

# %%
testdum = pd.get_dummies(testing[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked','Title', 'MultipleCabins', 
                                  'CabinDeck']])

# %%
traindum
# Out:
#               Age  SibSp  Parch  MultipleCabins  Pclass_1  Pclass_2  Pclass_3  \
# PassengerId
# 1            22.0      1      0               0         0         0         1
# 2            38.0      1      0               1         1         0         0
# 3            26.0      0      0               0         0         0         1
# 4            35.0      1      0               1         1         0         0
# 5            35.0      0      0               0         0         0         1
# ...           ...    ...    ...             ...       ...       ...       ...
# 887          27.0      0      0               0         0         1         0
# 888          19.0      0      0               1         1         0         0
# 889          28.0      1      2               0         0         0         1
# 890          26.0      0      0               1         1         0         0
# 891          32.0      0      0               0         0         0         1
#
#              Sex_female  Sex_male  Embarked_C  ...  Title_the Countess  \
# PassengerId                                    ...
# 1                     0         1           0  ...                   0
# 2                     1         0           1  ...                   0
# 3                     1         0           0  ...                   0
# 4                     1         0           0  ...                   0
# 5                     0         1           0  ...                   0
# ...                 ...       ...         ...  ...                 ...
# 887                   0         1           0  ...                   0
# 888                   1         0           0  ...                   0
# 889                   1         0           0  ...                   0
# 890                   0         1           1  ...                   0
# 891                   0         1           0  ...                   0
#
#              CabinDeck_A  CabinDeck_B  CabinDeck_C  CabinDeck_D  CabinDeck_E  \
# PassengerId
# 1                      0            0            0            0            0
# 2                      0            0            1            0            0
# 3                      0            0            0            0            0
# 4                      0            0            1            0            0
# 5                      0            0            0            0            0
# ...                  ...          ...          ...          ...          ...
# 887                    0            0            0            0            0
# 888                    0            1            0            0            0
# 889                    0            0            0            0            0
# 890                    0            0            1            0            0
# 891                    0            0            0            0            0
#
#              CabinDeck_F  CabinDeck_G  CabinDeck_T  CabinDeck_n
# PassengerId
# 1                      0            0            0            1
# 2                      0            0            0            0
# 3                      0            0            0            1
# 4                      0            0            0            0
# 5                      0            0            0            1
# ...                  ...          ...          ...          ...
# 887                    0            0            0            1
# 888                    0            0            0            0
# 889                    0            0            0            1
# 890                    0            0            0            0
# 891                    0            0            0            1
#
# [889 rows x 38 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
y_train = training["Survived"]

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked','Title', 'MultipleCabins', 'CabinDeck']
X_train = pd.get_dummies(training[features])
X_test = pd.get_dummies(testing[features])

# %%
gnb = GaussianNB()
cv = cross_val_score(gnb,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.66853933 0.70224719 0.76966292 0.76404494 0.72316384]
# 0.7255316447660763

# %%
lr = LogisticRegression(max_iter = 2000)
cv = cross_val_score(lr,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.83707865 0.81460674 0.82022472 0.81460674 0.84745763]
# 0.8267948962102455

# %%
dt = tree.DecisionTreeClassifier(random_state = 1)
cv = cross_val_score(dt,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1cbb27b90f4e> in <module>
# ----> 1 dt = tree.DecisionTreeClassifier(random_state = 1)
#       2 cv = cross_val_score(dt,X_train,y_train,cv=5)
#       3 print(cv)
#       4 print(cv.mean())
#
# NameError: name 'tree' is not defined

# %%
knn = KNeighborsClassifier()
cv = cross_val_score(knn,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.81460674 0.80898876 0.79213483 0.80898876 0.82485876]
# 0.8099155716371487

# %%
rf = RandomForestClassifier(random_state = 1)
cv = cross_val_score(rf,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.76404494 0.80337079 0.79775281 0.7752809  0.81355932]
# 0.790801752047229

# %%
svc = SVC(probability = True)
cv = cross_val_score(svc,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.6741573  0.7247191  0.68539326 0.70786517 0.71751412]
# 0.7019297911508919

# %%
from sklearn.ensemble import VotingClassifier
voting_clf = VotingClassifier(estimators = [('lr',lr),('knn',knn),('rf',rf),('gnb',gnb),('svc',svc)], voting = 'soft')

# %%
cv = cross_val_score(voting_clf,X_train,y_train,cv=5)
print(cv)
print(cv.mean())
# Out:
# [0.79213483 0.80337079 0.82022472 0.79775281 0.85310734]
# 0.8133180981400369

# %%
# With mean the results were, in order:
# gnb = 0.7255316447660763
# lr = 0.8267948962102455
# dt = 0.7874119215387545
# knn = 0.8019996191201676
# rf = 0.796419729575319
# svc = 0.696305465625595
# cv = 0.8155652891512727

# %%
# With median the results were, in order:
# gnb = 0.7255316447660763
# lr = 0.8267948962102455
# dt = 0.7862946740303435
# knn = 0.8099155716371487
# rf = 0.790801752047229
# svc = 0.7019297911508919
# cv = 0.8121945026344187

# %%
#Predictive analysis using Logistic Regression model
lr.fit(X_train,y_train)
#using features from test.csv(Class,Fare, Ticket etc...)
LR_Predicts=lr.predict(X_test)
#New dataset with predictions
LRoutput = pd.DataFrame({'Name': testing.Name, 'Survived': LR_Predicts})

#There is an error here because there are 8 fewer titles and 1 less CabinDeck
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-83631dc3663e> in <module>
#       2 lr.fit(X_train,y_train)
#       3 #using features from test.csv(Class,Fare, Ticket etc...)
# ----> 4 LR_Predicts=lr.predict(X_test)
#       5 #New dataset with predictions
#       6 LRoutput = pd.DataFrame({'Name': testing.Name, 'Survived': LR_Predicts})
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     286         n_features = self.coef_.shape[1]
#     287         if X.shape[1] != n_features:
# --> 288             raise ValueError("X has %d features per sample; expecting %d"
#     289                              % (X.shape[1], n_features))
#     290
#
# ValueError: X has 29 features per sample; expecting 38

# %%
dt.fit(X_train, y_train)
DT_Predicts=dt.predict(X_test)
DToutput = pd.DataFrame({'Pclass': testing.Pclass, 'Survived': DT_Predicts})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d87031193ed7> in <module>
# ----> 1 dt.fit(X_train, y_train)
#       2 DT_Predicts=dt.predict(X_test)
#       3 DToutput = pd.DataFrame({'Pclass': testing.Pclass, 'Survived': DT_Predicts})
#
# NameError: name 'dt' is not defined

# %%
knn.fit(X_train, y_train)
KNPred=knn.predict(X_test)
KNNoutput = pd.DataFrame({'Pclass': training.Pclass, 'Survived': KNPred})

# %%
rf.fit(X_train, y_train)
rfpred=rf.predict(X_test)
RFoutput=pd.DataFrame({'Pclass': training.Pclass, 'Survived': rfpred})

# %%
svc.fit(X_train, y_train)
svcpred=svc.predict(X_test)
SVCoutput=pd.DataFrame({'Pclass': training.Pclass, 'Survived': svcpred})

# %%
voting_clf.fit(X_train, y_train)
svcpred=svc.predict(X_test)
VOTEoutput=pd.DataFrame({'Pclass': training.Pclass, 'Survived': voting_clf})
